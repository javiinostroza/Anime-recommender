# %% [markdown]
# # Users Web Scrapping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time 
import csv 
from random import randint

# %%
def get_value(text):
    # Función para conseguir el texto entre los markups
    text = str(text)
    text = text.replace("\n", "").replace("\r", "").replace("\t", "")
    markup_count = text.count("</")
    position = -1
    for i in range(markup_count):
        position = text.find(">", position + 1)
    first_close = text.find("</")
    return text[position + 1: first_close]
    
def get_rating_value(text):
    # Función para conseguir el rating con el que se califica un anime
    text = str(text)
    text = text.replace("\n", "").replace("\r", "").replace("\t", "").replace(" ", "")
    rating_text = text.split(':')[-1]
    return rating_text.split('<')[0]

def get_anime_rating(text):
    # Función para conseguir un anime y su rating desde la lista de anime list de un usuario
    splited_obj = text.split(',')
    if len(splited_obj) == 28:
        anime_id = splited_obj[7].split('"anime_id":')[1]
        anime = splited_obj[4].split('"anime_title":"')[1][:-1]
        rating = splited_obj[0].split(':')[1]
        return (anime_id, anime, rating)
    return (None, None, None)

# %%
def product_female_user_list_data(total_data = 50000):
    '''
    Scrapping para obtener la calificación de los usuarios a los animé que han visto.
    Recibe como parámetro total_data, que corresponde al total de filas que se quiere obtener.
    '''

    base_url = 'https://myanimelist.net/'
    url = 'https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2'
    actual_url = 'https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=960'
    users_information = [[], []] # [ [username], [user gender]]
    ratings_information = [[], [], []] # [ [username], [anime], [overall rating] ]
    
    while True:
        print('actual url: ', actual_url)
        main_page = requests.get(actual_url)
        soup = BeautifulSoup(main_page.content, 'html.parser')
        tables = soup.find_all('table')
        user_rows = tables[1].find_all('tr')
    
        for row in user_rows:
            user_icons = row.find_all('td')
            for icon in user_icons:
                
                user_name = icon.find('div').find('a')
                user_name = get_value(user_name)
                users_information[0].append(user_name)
                
                user_href = icon.find('div').find('a', href=True)
                user_url = base_url + user_href['href']
                
                # Ingresamos al perfil del usuario para obtener género y anime list
                time.sleep(randint(1,6))
                user_page = requests.get(user_url)
                user_soup = BeautifulSoup(user_page.content, 'html.parser')
                user_info = user_soup.find('ul', {'class': 'user-status'})
                if user_info is None:
                    gender = 'Not Found'
                else:
                    span = user_info.find_all('li')[1].find_all('span')
                    if get_value(span[0]) == 'Gender':
                        gender = get_value(span[1])
                    else:
                        gender = 'None'
                users_information[1].append(gender)
                
                # Escribimos los datos del usuario en el csv
                with open('female_users.csv', mode='a') as users_file:
                    users_writer = csv.writer(users_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    users_writer.writerow([user_name, gender]) 
    
                user_lists = user_soup.find('div', {'class': 'user-button clearfix mb12'})
                user_anime_list = user_lists.find('a', href=True)
                user_anime_list_url = user_anime_list['href']
                
                # Ingresamos al anime list del usuario
                anime_list = requests.get(user_anime_list_url)
                anime_list_soup = BeautifulSoup(anime_list.content, 'html.parser')
                status_menu = anime_list_soup.find('div', {'class': 'status-menu-container'})
                if status_menu:
                    try:
                        completed_anime_list_url = status_menu.find('a', {'class': 'status-button completed'}, href=True)['href']

                        # Ingresamos a anime list completos para extraer su calificacion
                        completed_anime_list = requests.get(completed_anime_list_url)
                        completed_anime_list_soup = BeautifulSoup(completed_anime_list.content, 'html.parser')
                        completed_list = completed_anime_list_soup.find('div', {'class': 'list-unit completed'})

                        objects_completed_list = completed_list.find('table')['data-items']
                        objects_completed_list = objects_completed_list.split('"status":2,')

                        # Tomamos los datos de los distintos anime y guardamos el rating
                        for _object in objects_completed_list:
                            anime_id, anime, rating = get_anime_rating(_object)
                            if anime and rating:
                                ratings_information[0].append(user_name)
                                ratings_information[1].append(anime)
                                ratings_information[2].append(rating)
                                with open('female_ratings.csv', mode='a') as ratings_file:
                                    ratings_writer = csv.writer(ratings_file, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
                                    ratings_writer.writerow([user_name, anime_id, anime, rating]) 

                        # Revisamos si conseguimos el total de usuarios que queremos
                        print("users:info[0]: ", len(users_information[0]), " total_data: ", total_data)
                        if len(users_information[0]) == total_data:
                            print("break")
                            break
                            
                    except:
                        pass
            
            # Revisamos si conseguimos el total de usuarios que queremos
            print("users:info[0]: ", len(users_information[0]), " total_data: ", total_data)
            if len(users_information[0]) == total_data:
                print("break")
                break
                
         # Revisamos si conseguimos el total de usuarios que queremos
        print("users:info[0]: ", len(users_information[0]), " total_data: ", total_data)
        if len(users_information[0]) == total_data:
            print("break")
            break
        
        #Si aún no hemos conseguido la cantidad de datos buscada, cambiamos de url a la siguiente página y realizamos nuevamente el proceso.
        if actual_url == 'https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2': 
            next_page = url + '&show=24'
        else:
            next_page = '&show=' + str(int(actual_url.split('=')[-1]) + 24)
        actual_url = url + next_page
  
        
    return

# %%
product_female_user_list_data()
# Out:
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2
# users:info[0]:  1  total_data:  50000
# users:info[0]:  2  total_data:  50000
# users:info[0]:  3  total_data:  50000
# users:info[0]:  4  total_data:  50000
# users:info[0]:  5  total_data:  50000
# users:info[0]:  6  total_data:  50000
# users:info[0]:  6  total_data:  50000
# users:info[0]:  7  total_data:  50000
# users:info[0]:  8  total_data:  50000
# users:info[0]:  9  total_data:  50000
# users:info[0]:  10  total_data:  50000
# users:info[0]:  11  total_data:  50000
# users:info[0]:  12  total_data:  50000
# users:info[0]:  12  total_data:  50000
# users:info[0]:  13  total_data:  50000
# users:info[0]:  14  total_data:  50000
# users:info[0]:  16  total_data:  50000
# users:info[0]:  17  total_data:  50000
# users:info[0]:  18  total_data:  50000
# users:info[0]:  18  total_data:  50000
# users:info[0]:  19  total_data:  50000
# users:info[0]:  20  total_data:  50000
# users:info[0]:  22  total_data:  50000
# users:info[0]:  24  total_data:  50000
# users:info[0]:  24  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=24
# users:info[0]:  25  total_data:  50000
# users:info[0]:  26  total_data:  50000
# users:info[0]:  27  total_data:  50000
# users:info[0]:  28  total_data:  50000
# users:info[0]:  29  total_data:  50000
# users:info[0]:  30  total_data:  50000
# users:info[0]:  31  total_data:  50000
# users:info[0]:  32  total_data:  50000
# users:info[0]:  33  total_data:  50000
# users:info[0]:  35  total_data:  50000
# users:info[0]:  36  total_data:  50000
# users:info[0]:  36  total_data:  50000
# users:info[0]:  37  total_data:  50000
# users:info[0]:  38  total_data:  50000
# users:info[0]:  39  total_data:  50000
# users:info[0]:  40  total_data:  50000
# users:info[0]:  41  total_data:  50000
# users:info[0]:  42  total_data:  50000
# users:info[0]:  42  total_data:  50000
# users:info[0]:  43  total_data:  50000
# users:info[0]:  44  total_data:  50000
# users:info[0]:  45  total_data:  50000
# users:info[0]:  46  total_data:  50000
# users:info[0]:  47  total_data:  50000
# users:info[0]:  48  total_data:  50000
# users:info[0]:  48  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=48
# users:info[0]:  49  total_data:  50000
# users:info[0]:  50  total_data:  50000
# users:info[0]:  51  total_data:  50000
# users:info[0]:  52  total_data:  50000
# users:info[0]:  53  total_data:  50000
# users:info[0]:  54  total_data:  50000
# users:info[0]:  54  total_data:  50000
# users:info[0]:  55  total_data:  50000
# users:info[0]:  57  total_data:  50000
# users:info[0]:  58  total_data:  50000
# users:info[0]:  59  total_data:  50000
# users:info[0]:  60  total_data:  50000
# users:info[0]:  60  total_data:  50000
# users:info[0]:  61  total_data:  50000
# users:info[0]:  62  total_data:  50000
# users:info[0]:  63  total_data:  50000
# users:info[0]:  64  total_data:  50000
# users:info[0]:  65  total_data:  50000
# users:info[0]:  66  total_data:  50000
# users:info[0]:  66  total_data:  50000
# users:info[0]:  67  total_data:  50000
# users:info[0]:  68  total_data:  50000
# users:info[0]:  70  total_data:  50000
# users:info[0]:  72  total_data:  50000
# users:info[0]:  72  total_data:  50000
# users:info[0]:  72  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=72
# users:info[0]:  73  total_data:  50000
# users:info[0]:  75  total_data:  50000
# users:info[0]:  77  total_data:  50000
# users:info[0]:  78  total_data:  50000
# users:info[0]:  78  total_data:  50000
# users:info[0]:  79  total_data:  50000
# users:info[0]:  81  total_data:  50000
# users:info[0]:  82  total_data:  50000
# users:info[0]:  83  total_data:  50000
# users:info[0]:  84  total_data:  50000
# users:info[0]:  84  total_data:  50000
# users:info[0]:  85  total_data:  50000
# users:info[0]:  86  total_data:  50000
# users:info[0]:  87  total_data:  50000
# users:info[0]:  88  total_data:  50000
# users:info[0]:  90  total_data:  50000
# users:info[0]:  91  total_data:  50000
# users:info[0]:  92  total_data:  50000
# users:info[0]:  93  total_data:  50000
# users:info[0]:  94  total_data:  50000
# users:info[0]:  95  total_data:  50000
# users:info[0]:  96  total_data:  50000
# users:info[0]:  96  total_data:  50000
# users:info[0]:  96  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=96
# users:info[0]:  97  total_data:  50000
# users:info[0]:  98  total_data:  50000
# users:info[0]:  100  total_data:  50000
# users:info[0]:  101  total_data:  50000
# users:info[0]:  102  total_data:  50000
# users:info[0]:  103  total_data:  50000
# users:info[0]:  104  total_data:  50000
# users:info[0]:  105  total_data:  50000
# users:info[0]:  106  total_data:  50000
# users:info[0]:  107  total_data:  50000
# users:info[0]:  108  total_data:  50000
# users:info[0]:  109  total_data:  50000
# users:info[0]:  110  total_data:  50000
# users:info[0]:  111  total_data:  50000
# users:info[0]:  112  total_data:  50000
# users:info[0]:  114  total_data:  50000
# users:info[0]:  114  total_data:  50000
# users:info[0]:  115  total_data:  50000
# users:info[0]:  116  total_data:  50000
# users:info[0]:  117  total_data:  50000
# users:info[0]:  118  total_data:  50000
# users:info[0]:  119  total_data:  50000
# users:info[0]:  120  total_data:  50000
# users:info[0]:  120  total_data:  50000
# users:info[0]:  120  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=120
# users:info[0]:  121  total_data:  50000
# users:info[0]:  122  total_data:  50000
# users:info[0]:  124  total_data:  50000
# users:info[0]:  125  total_data:  50000
# users:info[0]:  126  total_data:  50000
# users:info[0]:  126  total_data:  50000
# users:info[0]:  127  total_data:  50000
# users:info[0]:  128  total_data:  50000
# users:info[0]:  129  total_data:  50000
# users:info[0]:  130  total_data:  50000
# users:info[0]:  131  total_data:  50000
# users:info[0]:  132  total_data:  50000
# users:info[0]:  134  total_data:  50000
# users:info[0]:  135  total_data:  50000
# users:info[0]:  136  total_data:  50000
# users:info[0]:  137  total_data:  50000
# users:info[0]:  138  total_data:  50000
# users:info[0]:  138  total_data:  50000
# users:info[0]:  139  total_data:  50000
# users:info[0]:  141  total_data:  50000
# users:info[0]:  142  total_data:  50000
# users:info[0]:  143  total_data:  50000
# users:info[0]:  144  total_data:  50000
# users:info[0]:  144  total_data:  50000
# users:info[0]:  144  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=144
# users:info[0]:  145  total_data:  50000
# users:info[0]:  146  total_data:  50000
# users:info[0]:  147  total_data:  50000
# users:info[0]:  148  total_data:  50000
# users:info[0]:  149  total_data:  50000
# users:info[0]:  150  total_data:  50000
# users:info[0]:  150  total_data:  50000
# users:info[0]:  151  total_data:  50000
# users:info[0]:  152  total_data:  50000
# users:info[0]:  153  total_data:  50000
# users:info[0]:  154  total_data:  50000
# users:info[0]:  155  total_data:  50000
# users:info[0]:  156  total_data:  50000
# users:info[0]:  156  total_data:  50000
# users:info[0]:  157  total_data:  50000
# users:info[0]:  159  total_data:  50000
# users:info[0]:  160  total_data:  50000
# users:info[0]:  161  total_data:  50000
# users:info[0]:  162  total_data:  50000
# users:info[0]:  162  total_data:  50000
# users:info[0]:  163  total_data:  50000
# users:info[0]:  164  total_data:  50000
# users:info[0]:  165  total_data:  50000
# users:info[0]:  167  total_data:  50000
# users:info[0]:  168  total_data:  50000
# users:info[0]:  168  total_data:  50000
# users:info[0]:  168  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=168
# users:info[0]:  169  total_data:  50000
# users:info[0]:  170  total_data:  50000
# users:info[0]:  171  total_data:  50000
# users:info[0]:  172  total_data:  50000
# users:info[0]:  173  total_data:  50000
# users:info[0]:  174  total_data:  50000
# users:info[0]:  175  total_data:  50000
# users:info[0]:  176  total_data:  50000
# users:info[0]:  177  total_data:  50000
# users:info[0]:  179  total_data:  50000
# users:info[0]:  180  total_data:  50000
# users:info[0]:  180  total_data:  50000
# users:info[0]:  181  total_data:  50000
# users:info[0]:  182  total_data:  50000
# users:info[0]:  183  total_data:  50000
# users:info[0]:  184  total_data:  50000
# users:info[0]:  185  total_data:  50000
# users:info[0]:  186  total_data:  50000
# users:info[0]:  186  total_data:  50000
# users:info[0]:  187  total_data:  50000
# users:info[0]:  188  total_data:  50000
# users:info[0]:  189  total_data:  50000
# users:info[0]:  190  total_data:  50000
# users:info[0]:  191  total_data:  50000
# users:info[0]:  192  total_data:  50000
# users:info[0]:  192  total_data:  50000
# users:info[0]:  192  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=192
# users:info[0]:  193  total_data:  50000
# users:info[0]:  194  total_data:  50000
# users:info[0]:  195  total_data:  50000
# users:info[0]:  196  total_data:  50000
# users:info[0]:  197  total_data:  50000
# users:info[0]:  198  total_data:  50000
# users:info[0]:  198  total_data:  50000
# users:info[0]:  199  total_data:  50000
# users:info[0]:  200  total_data:  50000
# users:info[0]:  201  total_data:  50000
# users:info[0]:  203  total_data:  50000
# users:info[0]:  204  total_data:  50000
# users:info[0]:  204  total_data:  50000
# users:info[0]:  205  total_data:  50000
# users:info[0]:  206  total_data:  50000
# users:info[0]:  207  total_data:  50000
# users:info[0]:  208  total_data:  50000
# users:info[0]:  209  total_data:  50000
# users:info[0]:  210  total_data:  50000
# users:info[0]:  210  total_data:  50000
# users:info[0]:  212  total_data:  50000
# users:info[0]:  213  total_data:  50000
# users:info[0]:  214  total_data:  50000
# users:info[0]:  215  total_data:  50000
# users:info[0]:  216  total_data:  50000
# users:info[0]:  216  total_data:  50000
# users:info[0]:  216  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=216
# users:info[0]:  218  total_data:  50000
# users:info[0]:  219  total_data:  50000
# users:info[0]:  220  total_data:  50000
# users:info[0]:  221  total_data:  50000
# users:info[0]:  222  total_data:  50000
# users:info[0]:  223  total_data:  50000
# users:info[0]:  224  total_data:  50000
# users:info[0]:  225  total_data:  50000
# users:info[0]:  226  total_data:  50000
# users:info[0]:  227  total_data:  50000
# users:info[0]:  228  total_data:  50000
# users:info[0]:  228  total_data:  50000
# users:info[0]:  229  total_data:  50000
# users:info[0]:  230  total_data:  50000
# users:info[0]:  231  total_data:  50000
# users:info[0]:  233  total_data:  50000
# users:info[0]:  234  total_data:  50000
# users:info[0]:  234  total_data:  50000
# users:info[0]:  235  total_data:  50000
# users:info[0]:  236  total_data:  50000
# users:info[0]:  237  total_data:  50000
# users:info[0]:  238  total_data:  50000
# users:info[0]:  239  total_data:  50000
# users:info[0]:  240  total_data:  50000
# users:info[0]:  240  total_data:  50000
# users:info[0]:  240  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=240
# users:info[0]:  241  total_data:  50000
# users:info[0]:  243  total_data:  50000
# users:info[0]:  245  total_data:  50000
# users:info[0]:  246  total_data:  50000
# users:info[0]:  246  total_data:  50000
# users:info[0]:  247  total_data:  50000
# users:info[0]:  248  total_data:  50000
# users:info[0]:  249  total_data:  50000
# users:info[0]:  250  total_data:  50000
# users:info[0]:  251  total_data:  50000
# users:info[0]:  252  total_data:  50000
# users:info[0]:  252  total_data:  50000
# users:info[0]:  253  total_data:  50000
# users:info[0]:  254  total_data:  50000
# users:info[0]:  255  total_data:  50000
# users:info[0]:  256  total_data:  50000
# users:info[0]:  257  total_data:  50000
# users:info[0]:  258  total_data:  50000
# users:info[0]:  258  total_data:  50000
# users:info[0]:  259  total_data:  50000
# users:info[0]:  260  total_data:  50000
# users:info[0]:  261  total_data:  50000
# users:info[0]:  262  total_data:  50000
# users:info[0]:  264  total_data:  50000
# users:info[0]:  264  total_data:  50000
# users:info[0]:  264  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=264
# users:info[0]:  266  total_data:  50000
# users:info[0]:  268  total_data:  50000
# users:info[0]:  269  total_data:  50000
# users:info[0]:  270  total_data:  50000
# users:info[0]:  270  total_data:  50000
# users:info[0]:  271  total_data:  50000
# users:info[0]:  272  total_data:  50000
# users:info[0]:  273  total_data:  50000
# users:info[0]:  274  total_data:  50000
# users:info[0]:  275  total_data:  50000
# users:info[0]:  276  total_data:  50000
# users:info[0]:  276  total_data:  50000
# users:info[0]:  277  total_data:  50000
# users:info[0]:  278  total_data:  50000
# users:info[0]:  279  total_data:  50000
# users:info[0]:  280  total_data:  50000
# users:info[0]:  281  total_data:  50000
# users:info[0]:  282  total_data:  50000
# users:info[0]:  282  total_data:  50000
# users:info[0]:  283  total_data:  50000
# users:info[0]:  284  total_data:  50000
# users:info[0]:  285  total_data:  50000
# users:info[0]:  286  total_data:  50000
# users:info[0]:  287  total_data:  50000
# users:info[0]:  288  total_data:  50000
# users:info[0]:  288  total_data:  50000
# users:info[0]:  288  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=288
# users:info[0]:  289  total_data:  50000
# users:info[0]:  290  total_data:  50000
# users:info[0]:  291  total_data:  50000
# users:info[0]:  292  total_data:  50000
# users:info[0]:  293  total_data:  50000
# users:info[0]:  294  total_data:  50000
# users:info[0]:  295  total_data:  50000
# users:info[0]:  296  total_data:  50000
# users:info[0]:  297  total_data:  50000
# users:info[0]:  299  total_data:  50000
# users:info[0]:  300  total_data:  50000
# users:info[0]:  300  total_data:  50000
# users:info[0]:  301  total_data:  50000
# users:info[0]:  302  total_data:  50000
# users:info[0]:  303  total_data:  50000
# users:info[0]:  304  total_data:  50000
# users:info[0]:  305  total_data:  50000
# users:info[0]:  306  total_data:  50000
# users:info[0]:  306  total_data:  50000
# users:info[0]:  308  total_data:  50000
# users:info[0]:  309  total_data:  50000
# users:info[0]:  310  total_data:  50000
# users:info[0]:  311  total_data:  50000
# users:info[0]:  312  total_data:  50000
# users:info[0]:  312  total_data:  50000
# users:info[0]:  312  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=312
# users:info[0]:  313  total_data:  50000
# users:info[0]:  315  total_data:  50000
# users:info[0]:  316  total_data:  50000
# users:info[0]:  317  total_data:  50000
# users:info[0]:  318  total_data:  50000
# users:info[0]:  319  total_data:  50000
# users:info[0]:  320  total_data:  50000
# users:info[0]:  321  total_data:  50000
# users:info[0]:  322  total_data:  50000
# users:info[0]:  323  total_data:  50000
# users:info[0]:  324  total_data:  50000
# users:info[0]:  324  total_data:  50000
# users:info[0]:  325  total_data:  50000
# users:info[0]:  326  total_data:  50000
# users:info[0]:  327  total_data:  50000
# users:info[0]:  328  total_data:  50000
# users:info[0]:  330  total_data:  50000
# users:info[0]:  330  total_data:  50000
# users:info[0]:  331  total_data:  50000
# users:info[0]:  333  total_data:  50000
# users:info[0]:  334  total_data:  50000
# users:info[0]:  335  total_data:  50000
# users:info[0]:  336  total_data:  50000
# users:info[0]:  336  total_data:  50000
# users:info[0]:  336  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=336
# users:info[0]:  337  total_data:  50000
# users:info[0]:  339  total_data:  50000
# users:info[0]:  340  total_data:  50000
# users:info[0]:  341  total_data:  50000
# users:info[0]:  342  total_data:  50000
# users:info[0]:  342  total_data:  50000
# users:info[0]:  343  total_data:  50000
# users:info[0]:  344  total_data:  50000
# users:info[0]:  345  total_data:  50000
# users:info[0]:  346  total_data:  50000
# users:info[0]:  347  total_data:  50000
# users:info[0]:  348  total_data:  50000
# users:info[0]:  349  total_data:  50000
# users:info[0]:  351  total_data:  50000
# users:info[0]:  354  total_data:  50000
# users:info[0]:  355  total_data:  50000
# users:info[0]:  356  total_data:  50000
# users:info[0]:  359  total_data:  50000
# users:info[0]:  360  total_data:  50000
# users:info[0]:  360  total_data:  50000
# users:info[0]:  360  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=360
# users:info[0]:  361  total_data:  50000
# users:info[0]:  363  total_data:  50000
# users:info[0]:  366  total_data:  50000
# users:info[0]:  366  total_data:  50000
# users:info[0]:  367  total_data:  50000
# users:info[0]:  368  total_data:  50000
# users:info[0]:  369  total_data:  50000
# users:info[0]:  370  total_data:  50000
# users:info[0]:  371  total_data:  50000
# users:info[0]:  372  total_data:  50000
# users:info[0]:  372  total_data:  50000
# users:info[0]:  373  total_data:  50000
# users:info[0]:  374  total_data:  50000
# users:info[0]:  375  total_data:  50000
# users:info[0]:  378  total_data:  50000
# users:info[0]:  382  total_data:  50000
# users:info[0]:  383  total_data:  50000
# users:info[0]:  384  total_data:  50000
# users:info[0]:  384  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=384
# users:info[0]:  385  total_data:  50000
# users:info[0]:  386  total_data:  50000
# users:info[0]:  387  total_data:  50000
# users:info[0]:  388  total_data:  50000
# users:info[0]:  390  total_data:  50000
# users:info[0]:  390  total_data:  50000
# users:info[0]:  391  total_data:  50000
# users:info[0]:  392  total_data:  50000
# users:info[0]:  393  total_data:  50000
# users:info[0]:  394  total_data:  50000
# users:info[0]:  395  total_data:  50000
# users:info[0]:  396  total_data:  50000
# users:info[0]:  396  total_data:  50000
# users:info[0]:  397  total_data:  50000
# users:info[0]:  398  total_data:  50000
# users:info[0]:  400  total_data:  50000
# users:info[0]:  401  total_data:  50000
# users:info[0]:  402  total_data:  50000
# users:info[0]:  402  total_data:  50000
# users:info[0]:  403  total_data:  50000
# users:info[0]:  404  total_data:  50000
# users:info[0]:  406  total_data:  50000
# users:info[0]:  407  total_data:  50000
# users:info[0]:  408  total_data:  50000
# users:info[0]:  408  total_data:  50000
# users:info[0]:  408  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=408
# users:info[0]:  409  total_data:  50000
# users:info[0]:  410  total_data:  50000
# users:info[0]:  411  total_data:  50000
# users:info[0]:  412  total_data:  50000
# users:info[0]:  413  total_data:  50000
# users:info[0]:  414  total_data:  50000
# users:info[0]:  415  total_data:  50000
# users:info[0]:  416  total_data:  50000
# users:info[0]:  417  total_data:  50000
# users:info[0]:  418  total_data:  50000
# users:info[0]:  419  total_data:  50000
# users:info[0]:  420  total_data:  50000
# users:info[0]:  420  total_data:  50000
# users:info[0]:  421  total_data:  50000
# users:info[0]:  422  total_data:  50000
# users:info[0]:  423  total_data:  50000
# users:info[0]:  424  total_data:  50000
# users:info[0]:  425  total_data:  50000
# users:info[0]:  426  total_data:  50000
# users:info[0]:  426  total_data:  50000
# users:info[0]:  428  total_data:  50000
# users:info[0]:  429  total_data:  50000
# users:info[0]:  430  total_data:  50000
# users:info[0]:  432  total_data:  50000
# users:info[0]:  432  total_data:  50000
# users:info[0]:  432  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=432
# users:info[0]:  433  total_data:  50000
# users:info[0]:  434  total_data:  50000
# users:info[0]:  435  total_data:  50000
# users:info[0]:  436  total_data:  50000
# users:info[0]:  438  total_data:  50000
# users:info[0]:  438  total_data:  50000
# users:info[0]:  439  total_data:  50000
# users:info[0]:  440  total_data:  50000
# users:info[0]:  441  total_data:  50000
# users:info[0]:  442  total_data:  50000
# users:info[0]:  443  total_data:  50000
# users:info[0]:  444  total_data:  50000
# users:info[0]:  444  total_data:  50000
# users:info[0]:  445  total_data:  50000
# users:info[0]:  446  total_data:  50000
# users:info[0]:  448  total_data:  50000
# users:info[0]:  450  total_data:  50000
# users:info[0]:  450  total_data:  50000
# users:info[0]:  451  total_data:  50000
# users:info[0]:  452  total_data:  50000
# users:info[0]:  453  total_data:  50000
# users:info[0]:  454  total_data:  50000
# users:info[0]:  456  total_data:  50000
# users:info[0]:  456  total_data:  50000
# users:info[0]:  456  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=456
# users:info[0]:  457  total_data:  50000
# users:info[0]:  458  total_data:  50000
# users:info[0]:  460  total_data:  50000
# users:info[0]:  461  total_data:  50000
# users:info[0]:  462  total_data:  50000
# users:info[0]:  462  total_data:  50000
# users:info[0]:  463  total_data:  50000
# users:info[0]:  464  total_data:  50000
# users:info[0]:  465  total_data:  50000
# users:info[0]:  466  total_data:  50000
# users:info[0]:  467  total_data:  50000
# users:info[0]:  468  total_data:  50000
# users:info[0]:  469  total_data:  50000
# users:info[0]:  470  total_data:  50000
# users:info[0]:  471  total_data:  50000
# users:info[0]:  472  total_data:  50000
# users:info[0]:  473  total_data:  50000
# users:info[0]:  474  total_data:  50000
# users:info[0]:  474  total_data:  50000
# users:info[0]:  475  total_data:  50000
# users:info[0]:  476  total_data:  50000
# users:info[0]:  477  total_data:  50000
# users:info[0]:  478  total_data:  50000
# users:info[0]:  479  total_data:  50000
# users:info[0]:  480  total_data:  50000
# users:info[0]:  480  total_data:  50000
# users:info[0]:  480  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=480
# users:info[0]:  482  total_data:  50000
# users:info[0]:  483  total_data:  50000
# users:info[0]:  484  total_data:  50000
# users:info[0]:  485  total_data:  50000
# users:info[0]:  486  total_data:  50000
# users:info[0]:  486  total_data:  50000
# users:info[0]:  487  total_data:  50000
# users:info[0]:  488  total_data:  50000
# users:info[0]:  489  total_data:  50000
# users:info[0]:  490  total_data:  50000
# users:info[0]:  491  total_data:  50000
# users:info[0]:  492  total_data:  50000
# users:info[0]:  492  total_data:  50000
# users:info[0]:  493  total_data:  50000
# users:info[0]:  494  total_data:  50000
# users:info[0]:  495  total_data:  50000
# users:info[0]:  496  total_data:  50000
# users:info[0]:  497  total_data:  50000
# users:info[0]:  498  total_data:  50000
# users:info[0]:  498  total_data:  50000
# users:info[0]:  499  total_data:  50000
# users:info[0]:  500  total_data:  50000
# users:info[0]:  501  total_data:  50000
# users:info[0]:  502  total_data:  50000
# users:info[0]:  503  total_data:  50000
# users:info[0]:  504  total_data:  50000
# users:info[0]:  504  total_data:  50000
# users:info[0]:  504  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=504
# users:info[0]:  505  total_data:  50000
# users:info[0]:  506  total_data:  50000
# users:info[0]:  507  total_data:  50000
# users:info[0]:  508  total_data:  50000
# users:info[0]:  509  total_data:  50000
# users:info[0]:  510  total_data:  50000
# users:info[0]:  510  total_data:  50000
# users:info[0]:  511  total_data:  50000
# users:info[0]:  512  total_data:  50000
# users:info[0]:  513  total_data:  50000
# users:info[0]:  514  total_data:  50000
# users:info[0]:  515  total_data:  50000
# users:info[0]:  516  total_data:  50000
# users:info[0]:  516  total_data:  50000
# users:info[0]:  517  total_data:  50000
# users:info[0]:  518  total_data:  50000
# users:info[0]:  519  total_data:  50000
# users:info[0]:  520  total_data:  50000
# users:info[0]:  522  total_data:  50000
# users:info[0]:  524  total_data:  50000
# users:info[0]:  525  total_data:  50000
# users:info[0]:  526  total_data:  50000
# users:info[0]:  528  total_data:  50000
# users:info[0]:  528  total_data:  50000
# users:info[0]:  528  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=528
# users:info[0]:  529  total_data:  50000
# users:info[0]:  531  total_data:  50000
# users:info[0]:  533  total_data:  50000
# users:info[0]:  534  total_data:  50000
# users:info[0]:  534  total_data:  50000
# users:info[0]:  535  total_data:  50000
# users:info[0]:  536  total_data:  50000
# users:info[0]:  538  total_data:  50000
# users:info[0]:  540  total_data:  50000
# users:info[0]:  540  total_data:  50000
# users:info[0]:  541  total_data:  50000
# users:info[0]:  542  total_data:  50000
# users:info[0]:  543  total_data:  50000
# users:info[0]:  544  total_data:  50000
# users:info[0]:  545  total_data:  50000
# users:info[0]:  546  total_data:  50000
# users:info[0]:  546  total_data:  50000
# users:info[0]:  547  total_data:  50000
# users:info[0]:  548  total_data:  50000
# users:info[0]:  550  total_data:  50000
# users:info[0]:  551  total_data:  50000
# users:info[0]:  552  total_data:  50000
# users:info[0]:  552  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=552
# users:info[0]:  553  total_data:  50000
# users:info[0]:  554  total_data:  50000
# users:info[0]:  556  total_data:  50000
# users:info[0]:  557  total_data:  50000
# users:info[0]:  558  total_data:  50000
# users:info[0]:  558  total_data:  50000
# users:info[0]:  559  total_data:  50000
# users:info[0]:  560  total_data:  50000
# users:info[0]:  561  total_data:  50000
# users:info[0]:  562  total_data:  50000
# users:info[0]:  564  total_data:  50000
# users:info[0]:  564  total_data:  50000
# users:info[0]:  565  total_data:  50000
# users:info[0]:  566  total_data:  50000
# users:info[0]:  567  total_data:  50000
# users:info[0]:  568  total_data:  50000
# users:info[0]:  569  total_data:  50000
# users:info[0]:  570  total_data:  50000
# users:info[0]:  570  total_data:  50000
# users:info[0]:  572  total_data:  50000
# users:info[0]:  573  total_data:  50000
# users:info[0]:  574  total_data:  50000
# users:info[0]:  575  total_data:  50000
# users:info[0]:  576  total_data:  50000
# users:info[0]:  576  total_data:  50000
# users:info[0]:  576  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=576
# users:info[0]:  577  total_data:  50000
# users:info[0]:  578  total_data:  50000
# users:info[0]:  579  total_data:  50000
# users:info[0]:  580  total_data:  50000
# users:info[0]:  581  total_data:  50000
# users:info[0]:  582  total_data:  50000
# users:info[0]:  582  total_data:  50000
# users:info[0]:  583  total_data:  50000
# users:info[0]:  584  total_data:  50000
# users:info[0]:  585  total_data:  50000
# users:info[0]:  586  total_data:  50000
# users:info[0]:  587  total_data:  50000
# users:info[0]:  588  total_data:  50000
# users:info[0]:  588  total_data:  50000
# users:info[0]:  589  total_data:  50000
# users:info[0]:  590  total_data:  50000
# users:info[0]:  591  total_data:  50000
# users:info[0]:  592  total_data:  50000
# users:info[0]:  593  total_data:  50000
# users:info[0]:  594  total_data:  50000
# users:info[0]:  594  total_data:  50000
# users:info[0]:  595  total_data:  50000
# users:info[0]:  596  total_data:  50000
# users:info[0]:  597  total_data:  50000
# users:info[0]:  598  total_data:  50000
# users:info[0]:  599  total_data:  50000
# users:info[0]:  600  total_data:  50000
# users:info[0]:  600  total_data:  50000
# users:info[0]:  600  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=600
# users:info[0]:  601  total_data:  50000
# users:info[0]:  602  total_data:  50000
# users:info[0]:  603  total_data:  50000
# users:info[0]:  604  total_data:  50000
# users:info[0]:  605  total_data:  50000
# users:info[0]:  606  total_data:  50000
# users:info[0]:  606  total_data:  50000
# users:info[0]:  607  total_data:  50000
# users:info[0]:  608  total_data:  50000
# users:info[0]:  609  total_data:  50000
# users:info[0]:  610  total_data:  50000
# users:info[0]:  611  total_data:  50000
# users:info[0]:  612  total_data:  50000
# users:info[0]:  612  total_data:  50000
# users:info[0]:  613  total_data:  50000
# users:info[0]:  614  total_data:  50000
# users:info[0]:  615  total_data:  50000
# users:info[0]:  616  total_data:  50000
# users:info[0]:  617  total_data:  50000
# users:info[0]:  618  total_data:  50000
# users:info[0]:  618  total_data:  50000
# users:info[0]:  619  total_data:  50000
# users:info[0]:  620  total_data:  50000
# users:info[0]:  621  total_data:  50000
# users:info[0]:  624  total_data:  50000
# users:info[0]:  624  total_data:  50000
# users:info[0]:  624  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=624
# users:info[0]:  625  total_data:  50000
# users:info[0]:  626  total_data:  50000
# users:info[0]:  627  total_data:  50000
# users:info[0]:  629  total_data:  50000
# users:info[0]:  630  total_data:  50000
# users:info[0]:  630  total_data:  50000
# users:info[0]:  631  total_data:  50000
# users:info[0]:  633  total_data:  50000
# users:info[0]:  634  total_data:  50000
# users:info[0]:  635  total_data:  50000
# users:info[0]:  636  total_data:  50000
# users:info[0]:  636  total_data:  50000
# users:info[0]:  637  total_data:  50000
# users:info[0]:  638  total_data:  50000
# users:info[0]:  639  total_data:  50000
# users:info[0]:  641  total_data:  50000
# users:info[0]:  642  total_data:  50000
# users:info[0]:  642  total_data:  50000
# users:info[0]:  643  total_data:  50000
# users:info[0]:  644  total_data:  50000
# users:info[0]:  646  total_data:  50000
# users:info[0]:  647  total_data:  50000
# users:info[0]:  648  total_data:  50000
# users:info[0]:  648  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=648
# users:info[0]:  649  total_data:  50000
# users:info[0]:  650  total_data:  50000
# users:info[0]:  653  total_data:  50000
# users:info[0]:  654  total_data:  50000
# users:info[0]:  654  total_data:  50000
# users:info[0]:  655  total_data:  50000
# users:info[0]:  656  total_data:  50000
# users:info[0]:  657  total_data:  50000
# users:info[0]:  658  total_data:  50000
# users:info[0]:  659  total_data:  50000
# users:info[0]:  660  total_data:  50000
# users:info[0]:  660  total_data:  50000
# users:info[0]:  661  total_data:  50000
# users:info[0]:  663  total_data:  50000
# users:info[0]:  664  total_data:  50000
# users:info[0]:  665  total_data:  50000
# users:info[0]:  666  total_data:  50000
# users:info[0]:  667  total_data:  50000
# users:info[0]:  670  total_data:  50000
# users:info[0]:  671  total_data:  50000
# users:info[0]:  672  total_data:  50000
# users:info[0]:  672  total_data:  50000
# users:info[0]:  672  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=672
# users:info[0]:  674  total_data:  50000
# users:info[0]:  675  total_data:  50000
# users:info[0]:  676  total_data:  50000
# users:info[0]:  677  total_data:  50000
# users:info[0]:  678  total_data:  50000
# users:info[0]:  682  total_data:  50000
# users:info[0]:  683  total_data:  50000
# users:info[0]:  684  total_data:  50000
# users:info[0]:  684  total_data:  50000
# users:info[0]:  685  total_data:  50000
# users:info[0]:  686  total_data:  50000
# users:info[0]:  688  total_data:  50000
# users:info[0]:  689  total_data:  50000
# users:info[0]:  690  total_data:  50000
# users:info[0]:  690  total_data:  50000
# users:info[0]:  691  total_data:  50000
# users:info[0]:  692  total_data:  50000
# users:info[0]:  693  total_data:  50000
# users:info[0]:  694  total_data:  50000
# users:info[0]:  695  total_data:  50000
# users:info[0]:  696  total_data:  50000
# users:info[0]:  696  total_data:  50000
# users:info[0]:  696  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=696
# users:info[0]:  697  total_data:  50000
# users:info[0]:  698  total_data:  50000
# users:info[0]:  699  total_data:  50000
# users:info[0]:  700  total_data:  50000
# users:info[0]:  701  total_data:  50000
# users:info[0]:  702  total_data:  50000
# users:info[0]:  702  total_data:  50000
# users:info[0]:  703  total_data:  50000
# users:info[0]:  704  total_data:  50000
# users:info[0]:  706  total_data:  50000
# users:info[0]:  707  total_data:  50000
# users:info[0]:  708  total_data:  50000
# users:info[0]:  708  total_data:  50000
# users:info[0]:  709  total_data:  50000
# users:info[0]:  710  total_data:  50000
# users:info[0]:  711  total_data:  50000
# users:info[0]:  712  total_data:  50000
# users:info[0]:  713  total_data:  50000
# users:info[0]:  714  total_data:  50000
# users:info[0]:  714  total_data:  50000
# users:info[0]:  715  total_data:  50000
# users:info[0]:  718  total_data:  50000
# users:info[0]:  719  total_data:  50000
# users:info[0]:  720  total_data:  50000
# users:info[0]:  720  total_data:  50000
# users:info[0]:  720  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=720
# users:info[0]:  722  total_data:  50000
# users:info[0]:  723  total_data:  50000
# users:info[0]:  724  total_data:  50000
# users:info[0]:  725  total_data:  50000
# users:info[0]:  726  total_data:  50000
# users:info[0]:  726  total_data:  50000
# users:info[0]:  727  total_data:  50000
# users:info[0]:  728  total_data:  50000
# users:info[0]:  730  total_data:  50000
# users:info[0]:  731  total_data:  50000
# users:info[0]:  732  total_data:  50000
# users:info[0]:  732  total_data:  50000
# users:info[0]:  734  total_data:  50000
# users:info[0]:  735  total_data:  50000
# users:info[0]:  737  total_data:  50000
# users:info[0]:  738  total_data:  50000
# users:info[0]:  738  total_data:  50000
# users:info[0]:  739  total_data:  50000
# users:info[0]:  740  total_data:  50000
# users:info[0]:  741  total_data:  50000
# users:info[0]:  742  total_data:  50000
# users:info[0]:  743  total_data:  50000
# users:info[0]:  744  total_data:  50000
# users:info[0]:  744  total_data:  50000
# users:info[0]:  744  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=744
# users:info[0]:  745  total_data:  50000
# users:info[0]:  748  total_data:  50000
# users:info[0]:  749  total_data:  50000
# users:info[0]:  750  total_data:  50000
# users:info[0]:  750  total_data:  50000
# users:info[0]:  751  total_data:  50000
# users:info[0]:  752  total_data:  50000
# users:info[0]:  753  total_data:  50000
# users:info[0]:  754  total_data:  50000
# users:info[0]:  755  total_data:  50000
# users:info[0]:  756  total_data:  50000
# users:info[0]:  756  total_data:  50000
# users:info[0]:  757  total_data:  50000
# users:info[0]:  758  total_data:  50000
# users:info[0]:  759  total_data:  50000
# users:info[0]:  761  total_data:  50000
# users:info[0]:  762  total_data:  50000
# users:info[0]:  762  total_data:  50000
# users:info[0]:  764  total_data:  50000
# users:info[0]:  766  total_data:  50000
# users:info[0]:  767  total_data:  50000
# users:info[0]:  768  total_data:  50000
# users:info[0]:  768  total_data:  50000
# users:info[0]:  768  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=768
# users:info[0]:  769  total_data:  50000
# users:info[0]:  770  total_data:  50000
# users:info[0]:  771  total_data:  50000
# users:info[0]:  773  total_data:  50000
# users:info[0]:  774  total_data:  50000
# users:info[0]:  775  total_data:  50000
# users:info[0]:  776  total_data:  50000
# users:info[0]:  777  total_data:  50000
# users:info[0]:  778  total_data:  50000
# users:info[0]:  779  total_data:  50000
# users:info[0]:  780  total_data:  50000
# users:info[0]:  780  total_data:  50000
# users:info[0]:  781  total_data:  50000
# users:info[0]:  782  total_data:  50000
# users:info[0]:  783  total_data:  50000
# users:info[0]:  784  total_data:  50000
# users:info[0]:  785  total_data:  50000
# users:info[0]:  786  total_data:  50000
# users:info[0]:  786  total_data:  50000
# users:info[0]:  787  total_data:  50000
# users:info[0]:  789  total_data:  50000
# users:info[0]:  790  total_data:  50000
# users:info[0]:  791  total_data:  50000
# users:info[0]:  792  total_data:  50000
# users:info[0]:  792  total_data:  50000
# users:info[0]:  792  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=792
# users:info[0]:  795  total_data:  50000
# users:info[0]:  796  total_data:  50000
# users:info[0]:  797  total_data:  50000
# users:info[0]:  798  total_data:  50000
# users:info[0]:  798  total_data:  50000
# users:info[0]:  800  total_data:  50000
# users:info[0]:  801  total_data:  50000
# users:info[0]:  802  total_data:  50000
# users:info[0]:  803  total_data:  50000
# users:info[0]:  804  total_data:  50000
# users:info[0]:  804  total_data:  50000
# users:info[0]:  805  total_data:  50000
# users:info[0]:  806  total_data:  50000
# users:info[0]:  807  total_data:  50000
# users:info[0]:  808  total_data:  50000
# users:info[0]:  809  total_data:  50000
# users:info[0]:  810  total_data:  50000
# users:info[0]:  810  total_data:  50000
# users:info[0]:  811  total_data:  50000
# users:info[0]:  812  total_data:  50000
# users:info[0]:  813  total_data:  50000
# users:info[0]:  814  total_data:  50000
# users:info[0]:  815  total_data:  50000
# users:info[0]:  816  total_data:  50000
# users:info[0]:  816  total_data:  50000
# users:info[0]:  816  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=816
# users:info[0]:  817  total_data:  50000
# users:info[0]:  818  total_data:  50000
# users:info[0]:  820  total_data:  50000
# users:info[0]:  821  total_data:  50000
# users:info[0]:  822  total_data:  50000
# users:info[0]:  823  total_data:  50000
# users:info[0]:  826  total_data:  50000
# users:info[0]:  827  total_data:  50000
# users:info[0]:  828  total_data:  50000
# users:info[0]:  828  total_data:  50000
# users:info[0]:  829  total_data:  50000
# users:info[0]:  830  total_data:  50000
# users:info[0]:  831  total_data:  50000
# users:info[0]:  833  total_data:  50000
# users:info[0]:  834  total_data:  50000
# users:info[0]:  834  total_data:  50000
# users:info[0]:  835  total_data:  50000
# users:info[0]:  836  total_data:  50000
# users:info[0]:  837  total_data:  50000
# users:info[0]:  838  total_data:  50000
# users:info[0]:  839  total_data:  50000
# users:info[0]:  840  total_data:  50000
# users:info[0]:  840  total_data:  50000
# users:info[0]:  840  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=840
# users:info[0]:  841  total_data:  50000
# users:info[0]:  842  total_data:  50000
# users:info[0]:  843  total_data:  50000
# users:info[0]:  844  total_data:  50000
# users:info[0]:  846  total_data:  50000
# users:info[0]:  846  total_data:  50000
# users:info[0]:  847  total_data:  50000
# users:info[0]:  848  total_data:  50000
# users:info[0]:  849  total_data:  50000
# users:info[0]:  850  total_data:  50000
# users:info[0]:  851  total_data:  50000
# users:info[0]:  852  total_data:  50000
# users:info[0]:  852  total_data:  50000
# users:info[0]:  853  total_data:  50000
# users:info[0]:  854  total_data:  50000
# users:info[0]:  855  total_data:  50000
# users:info[0]:  856  total_data:  50000
# users:info[0]:  857  total_data:  50000
# users:info[0]:  858  total_data:  50000
# users:info[0]:  858  total_data:  50000
# users:info[0]:  859  total_data:  50000
# users:info[0]:  860  total_data:  50000
# users:info[0]:  861  total_data:  50000
# users:info[0]:  862  total_data:  50000
# users:info[0]:  863  total_data:  50000
# users:info[0]:  864  total_data:  50000
# users:info[0]:  864  total_data:  50000
# users:info[0]:  864  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=864
# users:info[0]:  865  total_data:  50000
# users:info[0]:  866  total_data:  50000
# users:info[0]:  867  total_data:  50000
# users:info[0]:  868  total_data:  50000
# users:info[0]:  869  total_data:  50000
# users:info[0]:  870  total_data:  50000
# users:info[0]:  871  total_data:  50000
# users:info[0]:  872  total_data:  50000
# users:info[0]:  873  total_data:  50000
# users:info[0]:  874  total_data:  50000
# users:info[0]:  875  total_data:  50000
# users:info[0]:  876  total_data:  50000
# users:info[0]:  876  total_data:  50000
# users:info[0]:  877  total_data:  50000
# users:info[0]:  878  total_data:  50000
# users:info[0]:  879  total_data:  50000
# users:info[0]:  880  total_data:  50000
# users:info[0]:  881  total_data:  50000
# users:info[0]:  882  total_data:  50000
# users:info[0]:  882  total_data:  50000
# users:info[0]:  883  total_data:  50000
# users:info[0]:  884  total_data:  50000
# users:info[0]:  885  total_data:  50000
# users:info[0]:  887  total_data:  50000
# users:info[0]:  888  total_data:  50000
# users:info[0]:  888  total_data:  50000
# users:info[0]:  888  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=888
# users:info[0]:  889  total_data:  50000
# users:info[0]:  890  total_data:  50000
# users:info[0]:  891  total_data:  50000
# users:info[0]:  894  total_data:  50000
# users:info[0]:  894  total_data:  50000
# users:info[0]:  896  total_data:  50000
# users:info[0]:  897  total_data:  50000
# users:info[0]:  900  total_data:  50000
# users:info[0]:  900  total_data:  50000
# users:info[0]:  902  total_data:  50000
# users:info[0]:  903  total_data:  50000
# users:info[0]:  904  total_data:  50000
# users:info[0]:  905  total_data:  50000
# users:info[0]:  906  total_data:  50000
# users:info[0]:  906  total_data:  50000
# users:info[0]:  907  total_data:  50000
# users:info[0]:  908  total_data:  50000
# users:info[0]:  909  total_data:  50000
# users:info[0]:  910  total_data:  50000
# users:info[0]:  911  total_data:  50000
# users:info[0]:  912  total_data:  50000
# users:info[0]:  912  total_data:  50000
# users:info[0]:  912  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=912
# users:info[0]:  913  total_data:  50000
# users:info[0]:  914  total_data:  50000
# users:info[0]:  915  total_data:  50000
# users:info[0]:  916  total_data:  50000
# users:info[0]:  917  total_data:  50000
# users:info[0]:  918  total_data:  50000
# users:info[0]:  918  total_data:  50000
# users:info[0]:  919  total_data:  50000
# users:info[0]:  920  total_data:  50000
# users:info[0]:  921  total_data:  50000
# users:info[0]:  922  total_data:  50000
# users:info[0]:  923  total_data:  50000
# users:info[0]:  924  total_data:  50000
# users:info[0]:  924  total_data:  50000
# users:info[0]:  926  total_data:  50000
# users:info[0]:  927  total_data:  50000
# users:info[0]:  928  total_data:  50000
# users:info[0]:  930  total_data:  50000
# users:info[0]:  930  total_data:  50000
# users:info[0]:  931  total_data:  50000
# users:info[0]:  932  total_data:  50000
# users:info[0]:  933  total_data:  50000
# users:info[0]:  934  total_data:  50000
# users:info[0]:  935  total_data:  50000
# users:info[0]:  936  total_data:  50000
# users:info[0]:  936  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=936
# users:info[0]:  937  total_data:  50000
# users:info[0]:  938  total_data:  50000
# users:info[0]:  939  total_data:  50000
# users:info[0]:  940  total_data:  50000
# users:info[0]:  942  total_data:  50000
# users:info[0]:  942  total_data:  50000
# users:info[0]:  944  total_data:  50000
# users:info[0]:  945  total_data:  50000
# users:info[0]:  946  total_data:  50000
# users:info[0]:  947  total_data:  50000
# users:info[0]:  948  total_data:  50000
# users:info[0]:  949  total_data:  50000
# users:info[0]:  950  total_data:  50000
# users:info[0]:  951  total_data:  50000
# users:info[0]:  952  total_data:  50000
# users:info[0]:  953  total_data:  50000
# users:info[0]:  954  total_data:  50000
# users:info[0]:  954  total_data:  50000
# users:info[0]:  955  total_data:  50000
# users:info[0]:  956  total_data:  50000
# users:info[0]:  958  total_data:  50000
# users:info[0]:  960  total_data:  50000
# users:info[0]:  960  total_data:  50000
# users:info[0]:  960  total_data:  50000
# actual url:  https://myanimelist.net/users.php?cat=user&q=&loc=&agelow=0&agehigh=0&g=2&show=960
# users:info[0]:  963  total_data:  50000
# users:info[0]:  965  total_data:  50000
# users:info[0]:  966  total_data:  50000
# users:info[0]:  966  total_data:  50000
# users:info[0]:  967  total_data:  50000
# users:info[0]:  969  total_data:  50000
# users:info[0]:  970  total_data:  50000
# users:info[0]:  971  total_data:  50000
# users:info[0]:  972  total_data:  50000
# users:info[0]:  972  total_data:  50000
# users:info[0]:  974  total_data:  50000
# users:info[0]:  975  total_data:  50000
# users:info[0]:  976  total_data:  50000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-67169cb57b71> in <module>
# ----> 1 product_female_user_list_data()
#
# <ipython-input-3-09fecc4a812b> in product_female_user_list_data(total_data)
#      50
#      51                 user_lists = user_soup.find('div', {'class': 'user-button clearfix mb12'})
# ---> 52                 user_anime_list = user_lists.find('a', href=True)
#      53                 user_anime_list_url = user_anime_list['href']
#      54
#
# AttributeError: 'NoneType' object has no attribute 'find'
